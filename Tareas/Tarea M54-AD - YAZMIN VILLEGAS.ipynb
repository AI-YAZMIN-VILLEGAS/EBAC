# %%
#pip install boto3

# %% [markdown]
# # Conexión a la base de datos e importación del archivo de housing.

# %%
import boto3
import awswrangler as wr



# Create a boto3 session
session = boto3.Session(
    aws_access_key_id="AKIAS5IN3FQ6AX3LT475",
    aws_secret_access_key="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",
    region_name="us-east-1"
)

# %% [markdown]
# ### housing database

# %%
# Query Athena

df = wr.athena.read_sql_query(
    sql="SELECT * FROM house LIMIT 10",
    database="ebac-subfolders",
    boto3_session=session
)


print(df.head())
# Out:
#      id               date   price  bedrooms  bathrooms  sqft_living  \
# 0  <NA>  "20141013T000000"  221900         3       1.00         1180
# 1  <NA>  "20141209T000000"  538000         3       2.25         2570
# 2  <NA>  "20150225T000000"  180000         2       1.00          770
# 3  <NA>  "20141209T000000"  604000         4       3.00         1960
# 4  <NA>  "20150218T000000"  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     NaN           0     0  ...      7        1180              0
# 1      7242     NaN           0     0  ...      7        2170            400
# 2     10000     NaN           0     0  ...      6         770              0
# 3      5000     NaN           0     0  ...      7        1050            910
# 4      8080     NaN           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %% [markdown]
# ### columnas

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# Query Athena

df = wr.athena.read_sql_query(
    sql="SELECT max(bedrooms) as max_bedrooms FROM house",
    database="ebac-subfolders",
    boto3_session=session
)


print(df.head())
# Out:
#    max_bedrooms
# 0            33

# %%
# Query Athena

df = wr.athena.read_sql_query(
    sql="SELECT min(bedrooms) as min_bedrooms FROM house",
    database="ebac-subfolders",
    boto3_session=session
)


print(df.head())
# Out:
#    min_bedrooms
# 0             0

# %%
# Query Athena

df = wr.athena.read_sql_query(
    sql="SELECT avg(bedrooms) as average_bedrooms FROM house",
    database="ebac-subfolders",
    boto3_session=session
)


print(df.head())
# Out:
#    average_bedrooms
# 0          3.370842

# %%
# Query Athena

df = wr.athena.read_sql_query(
    sql="SELECT AVG(CAST(sqft_living AS DOUBLE)) AS tamano_casa_promedio_pies_cuadrados FROM house",
    database="ebac-subfolders",
    boto3_session=session
)


print(df.head())
# Out:
#    tamano_casa_promedio_pies_cuadrados
# 0                          2079.899736

# %%
# Query Athena

df = wr.athena.read_sql_query(
    sql="SELECT sum(CAST(waterfront AS DOUBLE)) AS casas_con_waterfront FROM house",
    database="ebac-subfolders",
    boto3_session=session
)


print(df.head())
# Out:
#    casas_con_waterfront
# 0                 163.0

# %%
# Query Athena

df = wr.athena.read_sql_query(
    sql="SELECT sum(CAST(view AS DOUBLE)) AS casas_con_vista FROM house",
    database="ebac-subfolders",
    boto3_session=session
)


print(df.head())
# Out:
#    casas_con_vista
# 0           5064.0
