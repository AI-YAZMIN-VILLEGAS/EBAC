# %% [markdown]
# # Introducción a las Series de Tiempo I

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import os

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("prodzar/stocks-historical-price-data")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/sarahivillegas/.cache/kagglehub/datasets/prodzar/stocks-historical-price-data/versions/1

# %%
df = pd.read_csv('./AAPL.csv',index_col='Date',parse_dates=['Date'])

# %%
df['Name'] = 'APPL'

# %%
df.sample()
# Out:
#                 Open       High        Low      Close    Volume  Dividends  \
# Date
# 2019-06-20  49.09685  49.155659  48.523478  48.873875  86056000        0.0
#
#             Stock Splits  Name
# Date
# 2019-06-20           0.0  APPL

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.head(10)
# Out:
#                  Open       High        Low      Close     Volume  Dividends  \
# Date
# 2019-05-31  43.181805  43.613062  42.877969  42.897572  108174400        0.0
# 2019-06-03  43.027439  43.595909  41.721424  42.463867  161584400        0.0
# 2019-06-04  42.988224  44.063910  42.762796  44.017353  123872000        0.0
# 2019-06-05  45.154295  45.328268  44.384898  44.727940  119093600        0.0
# 2019-06-06  44.860258  45.445882  44.632378  45.384624   90105200        0.0
# 2019-06-07  45.700720  47.026338  45.519399  46.592632  122737600        0.0
# 2019-06-10  46.999386  47.871695  46.952829  47.188061  104883600        0.0
# 2019-06-11  47.746726  48.026062  47.437989  47.734474  107731600        0.0
# 2019-06-12  47.523745  48.018709  47.386528  47.582554   73012800        0.0
# 2019-06-13  47.707525  48.219639  47.437994  47.572758   86698400        0.0
#
#             Stock Splits  Name
# Date
# 2019-05-31           0.0  APPL
# 2019-06-03           0.0  APPL
# 2019-06-04           0.0  APPL
# 2019-06-05           0.0  APPL
# 2019-06-06           0.0  APPL
# 2019-06-07           0.0  APPL
# 2019-06-10           0.0  APPL
# 2019-06-11           0.0  APPL
# 2019-06-12           0.0  APPL
# 2019-06-13           0.0  APPL

# %%
df.tail(10)
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2021-06-17  129.605821  132.351707  129.456037  131.592834   96721700
# 2021-06-18  130.514458  131.313248  130.045159  130.264832  108953300
# 2021-06-21  130.105073  132.211917  129.016708  132.102081   79663300
# 2021-06-22  131.932333  133.879413  131.423086  133.779556   74783600
# 2021-06-23  133.569887  134.119068  133.030687  133.499985   60214200
# 2021-06-24  134.248856  134.438574  132.731126  133.210419   68711000
# 2021-06-25  133.260356  133.689705  132.611319  132.910873   70783700
# 2021-06-28  133.210424  135.047667  133.150516  134.578369   62111300
# 2021-06-29  134.598343  136.285817  134.149019  136.126053   64556100
# 2021-06-30  135.966285  137.204435  135.666731  136.755112   63261400
#
#             Dividends  Stock Splits  Name
# Date
# 2021-06-17        0.0           0.0  APPL
# 2021-06-18        0.0           0.0  APPL
# 2021-06-21        0.0           0.0  APPL
# 2021-06-22        0.0           0.0  APPL
# 2021-06-23        0.0           0.0  APPL
# 2021-06-24        0.0           0.0  APPL
# 2021-06-25        0.0           0.0  APPL
# 2021-06-28        0.0           0.0  APPL
# 2021-06-29        0.0           0.0  APPL
# 2021-06-30        0.0           0.0  APPL

# %% [markdown]
# # Análisis Univariado

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 526 entries, 2019-05-31 to 2021-06-30
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          526 non-null    float64
#  1   High          526 non-null    float64
#  2   Low           526 non-null    float64
#  3   Close         526 non-null    float64
#  4   Volume        526 non-null    int64
#  5   Dividends     526 non-null    float64
#  6   Stock Splits  526 non-null    float64
#  7   Name          526 non-null    object
# dtypes: float64(6), int64(1), object(1)
# memory usage: 37.0+ KB

# %%
df.describe().T
# Out:
#               count          mean           std           min           25%  \
# Open          526.0  9.160830e+01  3.077559e+01  4.298822e+01  6.374861e+01
# High          526.0  9.272394e+01  3.107684e+01  4.359591e+01  6.491420e+01
# Low           526.0  9.049518e+01  3.027810e+01  4.172142e+01  6.337291e+01
# Close         526.0  9.165835e+01  3.067098e+01  4.246387e+01  6.427531e+01
# Volume        526.0  1.280820e+08  6.144065e+07  4.544800e+07  8.736720e+07
# Dividends     526.0  3.075095e-03  2.479227e-02  0.000000e+00  0.000000e+00
# Stock Splits  526.0  7.604563e-03  1.744083e-01  0.000000e+00  0.000000e+00
#
#                        50%           75%           max
# Open          8.686493e+01  1.224732e+02  1.429285e+02
# High          8.760879e+01  1.239515e+02  1.444115e+02
# Low           8.552844e+01  1.206813e+02  1.407089e+02
# Close         8.694675e+01  1.223111e+02  1.424905e+02
# Volume        1.112724e+08  1.507170e+08  4.265100e+08
# Dividends     0.000000e+00  0.000000e+00  2.200000e-01
# Stock Splits  0.000000e+00  0.000000e+00  4.000000e+00

# %%
pd.set_option('display.float_format',lambda x:'%.2f' % x)

# %%
df.describe().T
# Out:
#               count         mean         std         min         25%  \
# Open         526.00        91.61       30.78       42.99       63.75
# High         526.00        92.72       31.08       43.60       64.91
# Low          526.00        90.50       30.28       41.72       63.37
# Close        526.00        91.66       30.67       42.46       64.28
# Volume       526.00 128082046.01 61440648.41 45448000.00 87367200.00
# Dividends    526.00         0.00        0.02        0.00        0.00
# Stock Splits 526.00         0.01        0.17        0.00        0.00
#
#                       50%          75%          max
# Open                86.86       122.47       142.93
# High                87.61       123.95       144.41
# Low                 85.53       120.68       140.71
# Close               86.95       122.31       142.49
# Volume       111272350.00 150717025.00 426510000.00
# Dividends            0.00         0.00         0.22
# Stock Splits         0.00         0.00         4.00

# %%
df[df==0].count()/df.count()*100
# Out:
# Open            0.00
# High            0.00
# Low             0.00
# Close           0.00
# Volume          0.00
# Dividends      98.48
# Stock Splits   99.81
# Name            0.00
# dtype: float64

# %%
df.shape
# Out:
# (526, 8)

# %% [markdown]
# # Visualización de series de tiempo

# %%
df
# Out:
#              Open   High    Low  Close     Volume  Dividends  Stock Splits  \
# Date
# 2019-05-31  43.18  43.61  42.88  42.90  108174400       0.00          0.00
# 2019-06-03  43.03  43.60  41.72  42.46  161584400       0.00          0.00
# 2019-06-04  42.99  44.06  42.76  44.02  123872000       0.00          0.00
# 2019-06-05  45.15  45.33  44.38  44.73  119093600       0.00          0.00
# 2019-06-06  44.86  45.45  44.63  45.38   90105200       0.00          0.00
# ...           ...    ...    ...    ...        ...        ...           ...
# 2021-06-24 134.25 134.44 132.73 133.21   68711000       0.00          0.00
# 2021-06-25 133.26 133.69 132.61 132.91   70783700       0.00          0.00
# 2021-06-28 133.21 135.05 133.15 134.58   62111300       0.00          0.00
# 2021-06-29 134.60 136.29 134.15 136.13   64556100       0.00          0.00
# 2021-06-30 135.97 137.20 135.67 136.76   63261400       0.00          0.00
#
#             Name
# Date
# 2019-05-31  APPL
# 2019-06-03  APPL
# 2019-06-04  APPL
# 2019-06-05  APPL
# 2019-06-06  APPL
# ...          ...
# 2021-06-24  APPL
# 2021-06-25  APPL
# 2021-06-28  APPL
# 2021-06-29  APPL
# 2021-06-30  APPL
#
# [526 rows x 8 columns]

# %%
df['2019':'2021'].plot(subplots=True,figsize=(10,12))
plt.title('Precios 2019-2021')
plt.show()

# %%
df['Name'].unique()
# Out:
# array(['APPL'], dtype=object)

# %% [markdown]
# # Visualización de Lags
#  para cambios de tendencia o rupturas de la misma

# %%
df['Close'].asfreq('M').plot(legend=True)
lag = 12
shifted = df['Close'].asfreq('M').shift(lag).plot(legend=True)
shifted.legend(['Apple Close','Apple Lagged'])
plt.grid()
plt.show()

# %% [markdown]
# gráfico de cambio porcentual basado en el close

# %%
df['Change'] = df['Close'].div(df['Close'].shift())

# %%
pd.set_option('display.float_format',lambda x: '%.4f' % x)
df.head(20)
# Out:
#               Open    High     Low   Close     Volume  Dividends  \
# Date
# 2019-05-31 43.1818 43.6131 42.8780 42.8976  108174400     0.0000
# 2019-06-03 43.0274 43.5959 41.7214 42.4639  161584400     0.0000
# 2019-06-04 42.9882 44.0639 42.7628 44.0174  123872000     0.0000
# 2019-06-05 45.1543 45.3283 44.3849 44.7279  119093600     0.0000
# 2019-06-06 44.8603 45.4459 44.6324 45.3846   90105200     0.0000
# 2019-06-07 45.7007 47.0263 45.5194 46.5926  122737600     0.0000
# 2019-06-10 46.9994 47.8717 46.9528 47.1881  104883600     0.0000
# 2019-06-11 47.7467 48.0261 47.4380 47.7345  107731600     0.0000
# 2019-06-12 47.5237 48.0187 47.3865 47.5826   73012800     0.0000
# 2019-06-13 47.7075 48.2196 47.4380 47.5728   86698400     0.0000
# 2019-06-14 46.9357 47.4355 46.6294 47.2273   75046000     0.0000
# 2019-06-17 47.2665 47.7712 47.0876 47.5090   58676400     0.0000
# 2019-06-18 48.0383 49.0773 47.8325 48.6264  106204000     0.0000
# 2019-06-19 48.9278 48.9768 48.3471 48.4843   84496800     0.0000
# 2019-06-20 49.0968 49.1557 48.5235 48.8739   86056000     0.0000
# 2019-06-21 48.7122 49.2145 48.5529 48.7072  191202400     0.0000
# 2019-06-24 48.6484 49.0454 48.5578 48.6582   72881600     0.0000
# 2019-06-25 48.6215 48.8249 47.8521 47.9207   84281200     0.0000
# 2019-06-26 48.4598 49.2488 48.3569 48.9572  104270000     0.0000
# 2019-06-27 49.0772 49.3909 48.9008 48.9425   83598800     0.0000
#
#             Stock Splits  Name  Change
# Date
# 2019-05-31        0.0000  APPL     NaN
# 2019-06-03        0.0000  APPL  0.9899
# 2019-06-04        0.0000  APPL  1.0366
# 2019-06-05        0.0000  APPL  1.0161
# 2019-06-06        0.0000  APPL  1.0147
# 2019-06-07        0.0000  APPL  1.0266
# 2019-06-10        0.0000  APPL  1.0128
# 2019-06-11        0.0000  APPL  1.0116
# 2019-06-12        0.0000  APPL  0.9968
# 2019-06-13        0.0000  APPL  0.9998
# 2019-06-14        0.0000  APPL  0.9927
# 2019-06-17        0.0000  APPL  1.0060
# 2019-06-18        0.0000  APPL  1.0235
# 2019-06-19        0.0000  APPL  0.9971
# 2019-06-20        0.0000  APPL  1.0080
# 2019-06-21        0.0000  APPL  0.9966
# 2019-06-24        0.0000  APPL  0.9990
# 2019-06-25        0.0000  APPL  0.9848
# 2019-06-26        0.0000  APPL  1.0216
# 2019-06-27        0.0000  APPL  0.9997

# %%
df['Change'].plot(figsize=(20,8)).grid()

# %%
# calcular el retorno
df['Return'] = df.Change.sub(1).mul(100)

# %%
df.head(20)
# Out:
#               Open    High     Low   Close     Volume  Dividends  \
# Date
# 2019-05-31 43.1818 43.6131 42.8780 42.8976  108174400     0.0000
# 2019-06-03 43.0274 43.5959 41.7214 42.4639  161584400     0.0000
# 2019-06-04 42.9882 44.0639 42.7628 44.0174  123872000     0.0000
# 2019-06-05 45.1543 45.3283 44.3849 44.7279  119093600     0.0000
# 2019-06-06 44.8603 45.4459 44.6324 45.3846   90105200     0.0000
# 2019-06-07 45.7007 47.0263 45.5194 46.5926  122737600     0.0000
# 2019-06-10 46.9994 47.8717 46.9528 47.1881  104883600     0.0000
# 2019-06-11 47.7467 48.0261 47.4380 47.7345  107731600     0.0000
# 2019-06-12 47.5237 48.0187 47.3865 47.5826   73012800     0.0000
# 2019-06-13 47.7075 48.2196 47.4380 47.5728   86698400     0.0000
# 2019-06-14 46.9357 47.4355 46.6294 47.2273   75046000     0.0000
# 2019-06-17 47.2665 47.7712 47.0876 47.5090   58676400     0.0000
# 2019-06-18 48.0383 49.0773 47.8325 48.6264  106204000     0.0000
# 2019-06-19 48.9278 48.9768 48.3471 48.4843   84496800     0.0000
# 2019-06-20 49.0968 49.1557 48.5235 48.8739   86056000     0.0000
# 2019-06-21 48.7122 49.2145 48.5529 48.7072  191202400     0.0000
# 2019-06-24 48.6484 49.0454 48.5578 48.6582   72881600     0.0000
# 2019-06-25 48.6215 48.8249 47.8521 47.9207   84281200     0.0000
# 2019-06-26 48.4598 49.2488 48.3569 48.9572  104270000     0.0000
# 2019-06-27 49.0772 49.3909 48.9008 48.9425   83598800     0.0000
#
#             Stock Splits  Name  Change  Return
# Date
# 2019-05-31        0.0000  APPL     NaN     NaN
# 2019-06-03        0.0000  APPL  0.9899 -1.0110
# 2019-06-04        0.0000  APPL  1.0366  3.6584
# 2019-06-05        0.0000  APPL  1.0161  1.6143
# 2019-06-06        0.0000  APPL  1.0147  1.4682
# 2019-06-07        0.0000  APPL  1.0266  2.6617
# 2019-06-10        0.0000  APPL  1.0128  1.2779
# 2019-06-11        0.0000  APPL  1.0116  1.1579
# 2019-06-12        0.0000  APPL  0.9968 -0.3183
# 2019-06-13        0.0000  APPL  0.9998 -0.0206
# 2019-06-14        0.0000  APPL  0.9927 -0.7262
# 2019-06-17        0.0000  APPL  1.0060  0.5966
# 2019-06-18        0.0000  APPL  1.0235  2.3519
# 2019-06-19        0.0000  APPL  0.9971 -0.2923
# 2019-06-20        0.0000  APPL  1.0080  0.8036
# 2019-06-21        0.0000  APPL  0.9966 -0.3409
# 2019-06-24        0.0000  APPL  0.9990 -0.1006
# 2019-06-25        0.0000  APPL  0.9848 -1.5158
# 2019-06-26        0.0000  APPL  1.0216  2.1629
# 2019-06-27        0.0000  APPL  0.9997 -0.0300

# %%
df['Return'].plot(figsize=(20,8)).grid()

# %% [markdown]
# # Comparación de dos series

# %%
df2 = pd.read_csv('TSLA.csv',index_col='Date',parse_dates=['Date'])

# %%
df2.head(10)
# Out:
#               Open    High     Low   Close     Volume  Dividends  Stock Splits
# Date
# 2019-05-31 37.0200 37.9840 36.8200 37.0320   52033500          0        0.0000
# 2019-06-03 37.1020 37.3360 35.3980 35.7940   65322000          0        0.0000
# 2019-06-04 36.2200 38.7960 35.9220 38.7200   69037500          0        0.0000
# 2019-06-05 39.7360 40.2560 38.3700 39.3180   67554000          0        0.0000
# 2019-06-06 40.8880 42.2000 40.3600 41.1900  101211000          0        0.0000
# 2019-06-07 41.0000 42.1680 40.7000 40.9000   80017500          0        0.0000
# 2019-06-10 42.0500 43.3880 41.8020 42.5760   52925000          0        0.0000
# 2019-06-11 43.8280 44.1800 42.7000 43.4200   58267500          0        0.0000
# 2019-06-12 44.5900 44.6760 41.8000 41.8520   75987500          0        0.0000
# 2019-06-13 42.0760 42.9800 41.5020 42.7820   40841500          0        0.0000

# %%
df.head(10)
# Out:
#               Open    High     Low   Close     Volume  Dividends  \
# Date
# 2019-05-31 43.1818 43.6131 42.8780 42.8976  108174400     0.0000
# 2019-06-03 43.0274 43.5959 41.7214 42.4639  161584400     0.0000
# 2019-06-04 42.9882 44.0639 42.7628 44.0174  123872000     0.0000
# 2019-06-05 45.1543 45.3283 44.3849 44.7279  119093600     0.0000
# 2019-06-06 44.8603 45.4459 44.6324 45.3846   90105200     0.0000
# 2019-06-07 45.7007 47.0263 45.5194 46.5926  122737600     0.0000
# 2019-06-10 46.9994 47.8717 46.9528 47.1881  104883600     0.0000
# 2019-06-11 47.7467 48.0261 47.4380 47.7345  107731600     0.0000
# 2019-06-12 47.5237 48.0187 47.3865 47.5826   73012800     0.0000
# 2019-06-13 47.7075 48.2196 47.4380 47.5728   86698400     0.0000
#
#             Stock Splits  Name  Change  Return
# Date
# 2019-05-31        0.0000  APPL     NaN     NaN
# 2019-06-03        0.0000  APPL  0.9899 -1.0110
# 2019-06-04        0.0000  APPL  1.0366  3.6584
# 2019-06-05        0.0000  APPL  1.0161  1.6143
# 2019-06-06        0.0000  APPL  1.0147  1.4682
# 2019-06-07        0.0000  APPL  1.0266  2.6617
# 2019-06-10        0.0000  APPL  1.0128  1.2779
# 2019-06-11        0.0000  APPL  1.0116  1.1579
# 2019-06-12        0.0000  APPL  0.9968 -0.3183
# 2019-06-13        0.0000  APPL  0.9998 -0.0206

# %%
df['Close'].plot()
df2['Close'].plot()
plt.legend(['Apple','Tesla'])
plt.title('Comparación de precios Apple y Tesla - 2019-2021')
plt.show()

# %%
# se normaliza las vistas con base 100 para tener una base de comparación similar 
# la normalización toma como base el primer registro histórico (iloc[0])
# ambos precios empiezan en 100 
normal_apple = df['Close'].div(df['Close'].iloc[0]).mul(100)
normal_google = df2['Close'].div(df['Close'].iloc[0]).mul(100)
normal_apple.plot()
normal_google.plot()
plt.legend(['Apple','Tesla'])
plt.title('Comparación de precios Apple y Tesla - 2019-2021 NORMALIZADOS')
plt.show()

# %% [markdown]
# # Visualización de Medias

# %%
rolling2 = df2['Close'].rolling('90D').mean()
df2['Close'].plot()
rolling2.plot()
plt.title('Precio de cierre vs media movil 90D Apple 2019-2021')
plt.legend(['High','Rolling Mean'])

# %%
rolling2
# Out:
# Date
# 2019-05-31    37.0320
# 2019-06-03    36.4130
# 2019-06-04    37.1820
# 2019-06-05    37.7160
# 2019-06-06    38.4108
#                ...
# 2021-06-24   648.7590
# 2021-06-25   649.1259
# 2021-06-28   650.5926
# 2021-06-29   650.7995
# 2021-06-30   651.0890
# Name: Close, Length: 526, dtype: float64

# %% [markdown]
# # Visualizaciones financieras: Gráficos OHLC

# %%
pip install chart_studio
# Out:
# Requirement already satisfied: chart_studio in /opt/anaconda3/lib/python3.13/site-packages (1.1.0)
# Requirement already satisfied: plotly in /opt/anaconda3/lib/python3.13/site-packages (from chart_studio) (5.24.1)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.13/site-packages (from chart_studio) (2.32.3)
# Requirement already satisfied: retrying>=1.3.3 in /opt/anaconda3/lib/python3.13/site-packages (from chart_studio) (1.4.2)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.13/site-packages (from chart_studio) (1.17.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from plotly->chart_studio) (9.0.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from plotly->chart_studio) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests->chart_studio) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests->chart_studio) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests->chart_studio) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests->chart_studio) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline
from pylab import rcParams

from chart_studio import plotly
from chart_studio import grid_objs
import chart_studio.plotly as py
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)

import chart_studio.plotly as py
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.figure_factory as ff
import statsmodels.api as sm
from numpy.random import normal, seed
from scipy.stats import norm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import math
from sklearn.metrics import mean_absolute_error
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df2
# Out:
#                Open     High      Low    Close     Volume  Dividends  \
# Date
# 2019-05-31  37.0200  37.9840  36.8200  37.0320   52033500          0
# 2019-06-03  37.1020  37.3360  35.3980  35.7940   65322000          0
# 2019-06-04  36.2200  38.7960  35.9220  38.7200   69037500          0
# 2019-06-05  39.7360  40.2560  38.3700  39.3180   67554000          0
# 2019-06-06  40.8880  42.2000  40.3600  41.1900  101211000          0
# ...             ...      ...      ...      ...        ...        ...
# 2021-06-24 674.9900 697.6200 667.6100 679.8200   45982400          0
# 2021-06-25 689.5800 693.8100 668.7000 671.8700   32496700          0
# 2021-06-28 671.6400 694.7000 670.3200 688.7200   21628200          0
# 2021-06-29 684.6500 687.5100 675.8900 680.7600   17381300          0
# 2021-06-30 679.7700 692.8100 678.1400 679.7000   18924900          0
#
#             Stock Splits
# Date
# 2019-05-31        0.0000
# 2019-06-03        0.0000
# 2019-06-04        0.0000
# 2019-06-05        0.0000
# 2019-06-06        0.0000
# ...                  ...
# 2021-06-24        0.0000
# 2021-06-25        0.0000
# 2021-06-28        0.0000
# 2021-06-29        0.0000
# 2021-06-30        0.0000
#
# [526 rows x 7 columns]

# %%
df2.index = pd.to_datetime(df2.index)

june = df2.loc['2019-06']

import plotly.graph_objects as go
from plotly.offline import iplot

rango_ohlc = go.Ohlc(
    x=june.index,
    open=june['Open'],
    high=june['High'],
    low=june['Low'],
    close=june['Close']
)

iplot([rango_ohlc])
# Out:
# <div>                            <div id="8c3068ee-61c7-47e0-b224-8010c69463ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c3068ee-61c7-47e0-b224-8010c69463ab")) {                    Plotly.newPlot(                        "8c3068ee-61c7-47e0-b224-8010c69463ab",                        [{"close":[35.79399871826172,38.720001220703125,39.31800079345703,41.189998626708984,40.900001525878906,42.57600021362305,43.41999816894531,41.85200119018555,42.78200149536133,42.98400115966797,45.00600051879883,44.948001861572266,45.2859992980957,43.92399978637695,44.37200164794922,44.72800064086914,43.95199966430664,43.854000091552734,44.56800079345703,44.69200134277344],"high":[37.33599853515625,38.79600143432617,40.25600051879883,42.20000076293945,42.167999267578125,43.38800048828125,44.18000030517578,44.67599868774414,42.97999954223633,43.33000183105469,45.400001525878906,46.948001861572266,45.55400085449219,45.380001068115234,44.43600082397461,45.172000885009766,45.06800079345703,45.44599914550781,44.58000183105469,45.03400039672851],"low":[35.39799880981445,35.922000885009766,38.369998931884766,40.36000061035156,40.70000076293945,41.801998138427734,42.70000076293945,41.79999923706055,41.50199890136719,42.08000183105469,42.854000091552734,44.512001037597656,44.21200180053711,43.27000045776367,43.099998474121094,44.20399856567383,43.89799880981445,43.619998931884766,43.470001220703125,44.15999984741211],"open":[37.10200119018555,36.220001220703125,39.73600006103515,40.88800048828125,41.0,42.04999923706055,43.827999114990234,44.59000015258789,42.07600021362305,42.25,43.09600067138672,45.74399948120117,45.02199935913086,44.599998474121094,43.24399948120117,44.64799880981445,44.87799835205078,44.0620002746582,43.88999938964844,44.198001861572266],"x":["2019-06-03T00:00:00","2019-06-04T00:00:00","2019-06-05T00:00:00","2019-06-06T00:00:00","2019-06-07T00:00:00","2019-06-10T00:00:00","2019-06-11T00:00:00","2019-06-12T00:00:00","2019-06-13T00:00:00","2019-06-14T00:00:00","2019-06-17T00:00:00","2019-06-18T00:00:00","2019-06-19T00:00:00","2019-06-20T00:00:00","2019-06-21T00:00:00","2019-06-24T00:00:00","2019-06-25T00:00:00","2019-06-26T00:00:00","2019-06-27T00:00:00","2019-06-28T00:00:00"],"type":"ohlc"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921 ...

# %%
df2.index = pd.to_datetime(df2.index)

june = df2.loc['2020-06']

import plotly.graph_objects as go
from plotly.offline import iplot

rango_ohlc = go.Ohlc(
    x=june.index,
    open=june['Open'],
    high=june['High'],
    low=june['Low'],
    close=june['Close']
)

iplot([rango_ohlc])
# Out:
# <div>                            <div id="83cda42f-12d9-4974-8465-0859658d3bd9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83cda42f-12d9-4974-8465-0859658d3bd9")) {                    Plotly.newPlot(                        "83cda42f-12d9-4974-8465-0859658d3bd9",                        [{"close":[179.6199951171875,176.31199645996094,176.5919952392578,172.87600708007812,177.1320037841797,189.98399353027344,188.13400268554688,205.0099945068359,194.5679931640625,187.05599975585935,198.17999267578125,196.42599487304688,198.3580017089844,200.79200744628903,200.17999267578125,198.8639984130859,200.3560028076172,192.1699981689453,197.1959991455078,191.947998046875,201.8699951171875,215.9620056152344],"high":[179.8000030517578,181.73199462890625,179.58799743652344,179.14999389648438,177.3040008544922,190.0,190.88800048828125,205.4960021972656,203.79200744628903,197.5959930419922,199.76800537109375,202.5760040283203,201.0,203.83999633789065,203.19400024414065,201.7760009765625,202.3999938964844,200.17599487304688,197.1959991455078,199.0,202.0,217.5379943847656],"low":[170.82000732421875,174.1999969482422,176.02000427246094,171.68800354003906,173.24000549316406,181.83200073242188,184.78599548339844,196.5,194.3999938964844,182.52000427246097,181.6999969482422,192.47799682617188,196.51400756835935,198.8939971923828,198.26800537109375,198.0039978027344,198.802001953125,190.6280059814453,187.42999267578125,190.9739990234375,189.70399475097656,200.7460021972656],"open":[171.60000610351562,178.94000244140625,177.62399291992188,177.9759979248047,175.5679931640625,183.8000030517578,188.0019989013672,198.37600708007812,198.0399932861328,196.0,183.55799865722656,202.3699951171875,197.54200744628903,200.6000061035156,202.55599975585935,199.9900054931641,199.7760009765625,198.8220062255859,190.85400390625,198.95599365234375,193.802001953125,201.3000030517578],"x":["2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00"],"type":"ohlc"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444444 ...

# %%
df2.index = pd.to_datetime(df2.index)

june = df2.loc['2020-06']

import plotly.graph_objects as go
from plotly.offline import iplot

rango_ohlc = go.Candlestick(
    x=june.index,
    open=june['Open'],
    high=june['High'],
    low=june['Low'],
    close=june['Close']
)

iplot([rango_ohlc])
# Out:
# <div>                            <div id="57010f7d-70b6-4bd4-a256-f2fd17280317" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57010f7d-70b6-4bd4-a256-f2fd17280317")) {                    Plotly.newPlot(                        "57010f7d-70b6-4bd4-a256-f2fd17280317",                        [{"close":[179.6199951171875,176.31199645996094,176.5919952392578,172.87600708007812,177.1320037841797,189.98399353027344,188.13400268554688,205.0099945068359,194.5679931640625,187.05599975585935,198.17999267578125,196.42599487304688,198.3580017089844,200.79200744628903,200.17999267578125,198.8639984130859,200.3560028076172,192.1699981689453,197.1959991455078,191.947998046875,201.8699951171875,215.9620056152344],"high":[179.8000030517578,181.73199462890625,179.58799743652344,179.14999389648438,177.3040008544922,190.0,190.88800048828125,205.4960021972656,203.79200744628903,197.5959930419922,199.76800537109375,202.5760040283203,201.0,203.83999633789065,203.19400024414065,201.7760009765625,202.3999938964844,200.17599487304688,197.1959991455078,199.0,202.0,217.5379943847656],"low":[170.82000732421875,174.1999969482422,176.02000427246094,171.68800354003906,173.24000549316406,181.83200073242188,184.78599548339844,196.5,194.3999938964844,182.52000427246097,181.6999969482422,192.47799682617188,196.51400756835935,198.8939971923828,198.26800537109375,198.0039978027344,198.802001953125,190.6280059814453,187.42999267578125,190.9739990234375,189.70399475097656,200.7460021972656],"open":[171.60000610351562,178.94000244140625,177.62399291992188,177.9759979248047,175.5679931640625,183.8000030517578,188.0019989013672,198.37600708007812,198.0399932861328,196.0,183.55799865722656,202.3699951171875,197.54200744628903,200.6000061035156,202.55599975585935,199.9900054931641,199.7760009765625,198.8220062255859,190.85400390625,198.95599365234375,193.802001953125,201.3000030517578],"x":["2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00"],"type":"candlestick"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444 ...

# %%
df2['Close'].plot(figsize=(16,8)).grid()
plt.show()

# %%
rcParams['figure.figsize'] = 11,9
#decomposed_Tesla_volumen = sm.tsa.seasonal_decompose(df2['Close'],period=360)

#figure = decomposed_Tesla_volumen.plot()

#plt.grid()
#plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomposed = seasonal_decompose(
    df2['Close'],
    model='additive',
    period=5      # weekly seasonality (5 trading days)
)

decomposed.plot()
plt.grid()
plt.show()

# %%
df2.head(10)
# Out:
#               Open    High     Low   Close     Volume  Dividends  Stock Splits
# Date
# 2019-05-31 37.0200 37.9840 36.8200 37.0320   52033500          0        0.0000
# 2019-06-03 37.1020 37.3360 35.3980 35.7940   65322000          0        0.0000
# 2019-06-04 36.2200 38.7960 35.9220 38.7200   69037500          0        0.0000
# 2019-06-05 39.7360 40.2560 38.3700 39.3180   67554000          0        0.0000
# 2019-06-06 40.8880 42.2000 40.3600 41.1900  101211000          0        0.0000
# 2019-06-07 41.0000 42.1680 40.7000 40.9000   80017500          0        0.0000
# 2019-06-10 42.0500 43.3880 41.8020 42.5760   52925000          0        0.0000
# 2019-06-11 43.8280 44.1800 42.7000 43.4200   58267500          0        0.0000
# 2019-06-12 44.5900 44.6760 41.8000 41.8520   75987500          0        0.0000
# 2019-06-13 42.0760 42.9800 41.5020 42.7820   40841500          0        0.0000

# %%
ma_tesla = df2.rolling(window=60)
ma_tesla_mean = ma_tesla.mean()

# %%
ma_tesla_mean.tail(20)
# Out:
#                Open     High      Low    Close        Volume  Dividends  \
# Date
# 2021-06-03 662.0180 675.4122 645.8847 660.5220 32699413.3333     0.0000
# 2021-06-04 660.0082 673.4582 644.5870 659.3718 32089933.3333     0.0000
# 2021-06-07 658.2153 671.9165 643.0153 657.7973 31861430.0000     0.0000
# 2021-06-08 657.4322 670.7200 641.8380 656.2950 31735923.3333     0.0000
# 2021-06-09 655.9002 669.0302 640.3978 654.4757 31523406.6667     0.0000
# 2021-06-10 654.2423 667.5080 639.2228 653.3630 31385471.6667     0.0000
# 2021-06-11 653.4650 665.9885 638.3980 651.8310 30982685.0000     0.0000
# 2021-06-14 652.2640 664.9262 637.6843 651.2398 30769338.3333     0.0000
# 2021-06-15 651.7655 664.2522 637.2445 650.3147 30350506.6667     0.0000
# 2021-06-16 650.3147 662.7335 635.9903 649.2292 30061038.3333     0.0000
# 2021-06-17 649.0833 661.7947 635.0542 648.4698 29931196.6667     0.0000
# 2021-06-18 648.1743 661.1335 634.7490 648.3538 29777291.6667     0.0000
# 2021-06-21 648.3657 660.8983 634.7387 648.0278 29537088.3333     0.0000
# 2021-06-22 647.9720 660.6442 634.9988 648.1112 29292190.0000     0.0000
# 2021-06-23 648.2447 661.3228 635.5658 648.8658 29333226.6667     0.0000
# 2021-06-24 649.4653 662.3222 636.8425 649.6025 29442393.3333     0.0000
# 2021-06-25 650.1813 662.6857 637.3023 649.6682 29428383.3333     0.0000
# 2021-06-28 649.9025 662.7237 637.4840 650.1177 29200546.6667     0.0000
# 2021-06-29 649.5182 662.3795 637.3372 649.9462 28792855.0000     0.0000
# 2021-06-30 649.3427 662.3172 637.2833 649.7475 28637073.3333     0.0000
#
#             Stock Splits
# Date
# 2021-06-03        0.0000
# 2021-06-04        0.0000
# 2021-06-07        0.0000
# 2021-06-08        0.0000
# 2021-06-09        0.0000
# 2021-06-10        0.0000
# 2021-06-11        0.0000
# 2021-06-14        0.0000
# 2021-06-15        0.0000
# 2021-06-16        0.0000
# 2021-06-17        0.0000
# 2021-06-18        0.0000
# 2021-06-21        0.0000
# 2021-06-22        0.0000
# 2021-06-23        0.0000
# 2021-06-24        0.0000
# 2021-06-25        0.0000
# 2021-06-28        0.0000
# 2021-06-29        0.0000
# 2021-06-30        0.0000

# %%
df2['Close'].plot()
ma_tesla_mean['Close'].plot(color='red')
plt.grid()
plt.show()

# %%
df2.shape
# Out:
# (526, 7)

# %%
train_len = 450
train = df2[0:train_len]
test = df2[train_len:]

# %%
y_pred_sma = df2.copy()
ma_window = 30
y_pred_sma['sma_forecast'] = df2['High'].rolling(ma_window).mean()
y_pred_sma['sma_forecast'][train_len] = y_pred_sma['sma_forecast'][train_len-1]

# %%
y_pred_sma
# Out:
#                Open     High      Low    Close     Volume  Dividends  \
# Date
# 2019-05-31  37.0200  37.9840  36.8200  37.0320   52033500          0
# 2019-06-03  37.1020  37.3360  35.3980  35.7940   65322000          0
# 2019-06-04  36.2200  38.7960  35.9220  38.7200   69037500          0
# 2019-06-05  39.7360  40.2560  38.3700  39.3180   67554000          0
# 2019-06-06  40.8880  42.2000  40.3600  41.1900  101211000          0
# ...             ...      ...      ...      ...        ...        ...
# 2021-06-24 674.9900 697.6200 667.6100 679.8200   45982400          0
# 2021-06-25 689.5800 693.8100 668.7000 671.8700   32496700          0
# 2021-06-28 671.6400 694.7000 670.3200 688.7200   21628200          0
# 2021-06-29 684.6500 687.5100 675.8900 680.7600   17381300          0
# 2021-06-30 679.7700 692.8100 678.1400 679.7000   18924900          0
#
#             Stock Splits  sma_forecast
# Date
# 2019-05-31        0.0000           NaN
# 2019-06-03        0.0000           NaN
# 2019-06-04        0.0000           NaN
# 2019-06-05        0.0000           NaN
# 2019-06-06        0.0000           NaN
# ...                  ...           ...
# 2021-06-24        0.0000      617.0047
# 2021-06-25        0.0000      619.9163
# 2021-06-28        0.0000      623.3107
# 2021-06-29        0.0000      626.5700
# 2021-06-30        0.0000      629.7887
#
# [526 rows x 8 columns]

# %%
plt.figure(figsize=(20,5))
plt.grid()
plt.plot(train['High'],label='Train')
plt.plot(test['High'],label='Test')
plt.plot(y_pred_sma['sma_forecast'],label='Predicción Media Móvil')
plt.legend(loc='best')
plt.title('Predicción Simple com Media Móvil')
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.grid()
plt.plot(train['High'],label='Train')
plt.plot(test['High'],label='Test')
plt.plot(y_pred_sma['sma_forecast'],label='Predicción Media Móvil')
plt.legend(loc='best')
plt.title('Predicción simple con media móvil')
plt.show()

# %%
from sklearn.metrics import mean_absolute_error
rmse = np.sqrt(mean_absolute_error(test['High'], y_pred_sma['sma_forecast'][train_len:])).round(2)
mape = np.round(np.mean(np.abs(test['High']-y_pred_sma['sma_forecast'][train_len])/test['High'])*100*2)

results = pd.DataFrame({'Method':['Simple moving average forecast'], 'MAPE':[mape],'RMSE':[rmse]})
results = results[['Method','RMSE','MAPE']]
results
# Out:
#                            Method   RMSE    MAPE
# 0  Simple moving average forecast 6.7000 33.0000

# %%
y_comparison = pd.DataFrame().assign(forecast=y_pred_sma['sma_forecast'])
y_comparison['observed'] = df2['High']

# %%
y_comparison.tail(100)
# Out:
#             forecast  observed
# Date
# 2021-02-08  823.0123  877.7700
# 2021-02-09  829.4693  859.8000
# 2021-02-10  834.9167  844.8200
# 2021-02-11  840.2493  829.8800
# 2021-02-12  844.2737  817.3300
# ...              ...       ...
# 2021-06-24  617.0047  697.6200
# 2021-06-25  619.9163  693.8100
# 2021-06-28  623.3107  694.7000
# 2021-06-29  626.5700  687.5100
# 2021-06-30  629.7887  692.8100
#
# [100 rows x 2 columns]
