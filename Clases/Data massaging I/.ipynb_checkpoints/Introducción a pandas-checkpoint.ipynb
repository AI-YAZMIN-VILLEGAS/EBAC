# %%
import pandas as pd
import numpy as np
import os

df = pd.read_csv('netflix_titles.csv')

# %%
df[0:5]
# Out:
#    Unnamed: 0 show_id     type                  title         director  \
# 0           0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2  TV Show          Blood & Water              NaN
# 2           2      s3  TV Show              Ganglands  Julien Leclercq
# 3           3      s4  TV Show  Jailbirds New Orleans              NaN
# 4           4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 show_id     type                  title         director  \
# 0           0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2  TV Show          Blood & Water              NaN
# 2           2      s3  TV Show              Ganglands  Julien Leclercq
# 3           3      s4  TV Show  Jailbirds New Orleans              NaN
# 4           4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0 show_id     type        title         director  \
# 8802        8802   s8803    Movie       Zodiac    David Fincher
# 8803        8803   s8804  TV Show  Zombie Dumb              NaN
# 8804        8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805        8805   s8806    Movie         Zoom     Peter Hewitt
# 8806        8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# ...

# %%
df.tail(3)
# Out:
#       Unnamed: 0 show_id   type       title         director  \
# 8804        8804   s8805  Movie  Zombieland  Ruben Fleischer
# 8805        8805   s8806  Movie        Zoom     Peter Hewitt
# 8806        8806   s8807  Movie      Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#             date_added  release_year rating duration  \
# 8804  November 1, 2019          2009      R   88 min
# 8805  January 11, 2020          2006     PG   88 min
# 8806     March 2, 2019          2015  TV-14  111 min
#
#                                            listed_in  \
# 8804                         Comedies, Horror Movies
# 8805              Children & Family Movies, Comedies
# ...

# %%
df.sample(5)
# Out:
#       Unnamed: 0 show_id   type              title        director  \
# 2252        2252   s2253  Movie    Your Excellency  Funke Akindele
# 5044        5044   s5045  Movie  When We First Met      Ari Sandel
# 2843        2843   s2844  Movie             Aurora     Cristi Puiu
# 6708        6708   s6709  Movie           Euphoria  Valeria Golino
# 5472        5472   s5473  Movie              Raees  Rahul Dholakia
#
#                                                    cast  \
# 2252  Akin Lewis, Funke Akindele, Kemi Lala Akindoju...
# 5044  Adam DeVine, Alexandra Daddario, Shelley Henni...
# 2843  Cristi Puiu, Clara Voda, Catrinel Dumitrescu, ...
# 6708  Riccardo Scamarcio, Valerio Mastandrea, Isabel...
# 5472  Shah Rukh Khan, Mahira Khan, Nawazuddin Siddiq...
#
#                                     country        date_added  release_year  \
# 2252                                    NaN     July 10, 2020          2019
# ...

# %%
df.describe().T
# Out:
#                count         mean          std     min     25%     50%  \
# Unnamed: 0    8807.0  4403.000000  2542.506244     0.0  2201.5  4403.0
# release_year  8807.0  2014.180198     8.819312  1925.0  2013.0  2017.0
# duration_num  8807.0    69.848530    50.806431     1.0     2.0    88.0
#
#                  75%     max
# Unnamed: 0    6604.5  8806.0
# release_year  2019.0  2021.0
# duration_num   106.0   312.0

# %%
df['release_year'].plot()
# Out:
# <Axes: >

# %%
df['release_year'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.dtypes
# Out:
# Unnamed: 0         int64
# show_id           object
# type              object
# title             object
# director          object
# cast              object
# country           object
# date_added        object
# release_year       int64
# rating            object
# duration          object
# listed_in         object
# description       object
# duration_num     float64
# duration_unit     object
# dtype: object

# %%
df.groupby('type').count()['country']
# Out:
# type
# Movie      5691
# TV Show    2285
# Name: country, dtype: int64

# %%
df.groupby('country').count()['show_id'].sort_values(ascending=False)[:10]
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: show_id, dtype: int64

# %%
df.groupby('country').count()['show_id']
# Out:
# country
# , France, Algeria                                       1
# , South Korea                                           1
# Argentina                                              56
# Argentina, Brazil, France, Poland, Germany, Denmark     1
# Argentina, Chile                                        2
#                                                        ..
# Venezuela                                               1
# Venezuela, Colombia                                     1
# Vietnam                                                 7
# West Germany                                            1
# Zimbabwe                                                1
# Name: show_id, Length: 748, dtype: int64

# %%
df.groupby('country').count()['show_id'].sort_values(ascending=False)[:10].plot.bar()
# Out:
# <Axes: xlabel='country'>

# %%
df.groupby('director').count()['country'].sort_values(ascending=False)[:5]
# Out:
# director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              15
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Name: country, dtype: int64

# %%
df.to_numpy()
# Out:
# array([[0, 's1', 'Movie', ...,
#         'As her father nears the end of his life, filmmaker Kirsten Johnson stages his death in inventive and comical ways to help them both face the inevitable.',
#         90.0, 'min'],
#        [1, 's2', 'TV Show', ...,
#         'After crossing paths at a party, a Cape Town teen sets out to prove whether a private-school swimming star is her sister who was abducted at birth.',
#         2.0, 'season'],
#        [2, 's3', 'TV Show', ...,
#         'To protect his family from a powerful drug lord, skilled thief Mehdi and his expert team of robbers are pulled into a violent and deadly turf war.',
#         1.0, 'season'],
#        ...,
#        [8804, 's8805', 'Movie', ...,
#         'Looking to survive in a world taken over by zombies, a dorky college student teams with an urban roughneck and a pair of grifter sisters.',
#         88.0, 'min'],
#        [8805, 's8806', 'Movie', ...,
# ...

# %%
df['duration_num'] = df['duration']

# %%
df['duration_unit'] = ''

# %%
df.head(3)
# Out:
#    Unnamed: 0 show_id     type                 title         director  \
# 0           0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2  TV Show         Blood & Water              NaN
# 2           2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# ...

# %%
df['duration_unit'] = df['duration_unit'].astype(pd.StringDtype())

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'rating', 'duration', 'listed_in', 'description', 'duration_num'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0                int64
# show_id                  object
# type                     object
# title                    object
# director                 object
# cast                     object
# country                  object
# date_added               object
# release_year              int64
# rating                   object
# duration                 object
# listed_in                object
# description              object
# duration_num             object
# duration_unit    string[python]
# dtype: object

# %%
stringcols = df.select_dtypes(include='object').columns

# %%
df[stringcols] = df[stringcols].fillna('').astype(pd.StringDtype())

# %%
df.dtypes
# Out:
# Unnamed: 0                int64
# show_id          string[python]
# type             string[python]
# title            string[python]
# director         string[python]
# cast             string[python]
# country          string[python]
# date_added       string[python]
# release_year              int64
# rating           string[python]
# duration         string[python]
# listed_in        string[python]
# description      string[python]
# duration_num     string[python]
# duration_unit    string[python]
# dtype: object

# %%
df.head(3)
# Out:
#    Unnamed: 0 show_id     type                 title         director  \
# 0           0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2  TV Show         Blood & Water
# 2           2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                     United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
df['duration_unit'] = 'min'

# %%
df.head(3)
# Out:
#    Unnamed: 0 show_id     type                 title         director  \
# 0           0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2  TV Show         Blood & Water
# 2           2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                     United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
df['duration_unit'] = df['duration_unit'].where(df.duration_num.str.endswith('min'),'season')

# %%
df.sample(5)
# Out:
#       Unnamed: 0 show_id     type                   title  \
# 6095        6095   s6096    Movie         After Porn Ends
# 7066        7066   s7067    Movie           Incorruptible
# 8076        8076   s8077    Movie   Spy Kids 3: Game Over
# 8416        8416   s8417    Movie  The Matrix Revolutions
# 7404        7404   s7405  TV Show         Marching Orders
#
#                              director  \
# 6095                    Bryce Wagoner
# 7066        Elizabeth Chai Vasarhelyi
# 8076                 Robert Rodriguez
# 8416  Lilly Wachowski, Lana Wachowski
# 7404
#
#                                                    cast  \
# 6095
# 7066
# 8076  Daryl Sabara, Sylvester Stallone, Ricardo Mont...
# 8416  Keanu Reeves, Laurence Fishburne, Carrie-Anne ...
# 7404
#
#                      country         date_added  release_year rating  \
# 6095           United States       May 27, 2019          2012     NR
# 7066  United States, Senegal  September 1, 2017          2015  TV-MA
# ...

# %%
df['duration_num'] = df['duration_num'].replace({'min':'','Season':'','Seasons':'','s':''},regex=True)

# %%
df.sample(5)
# Out:
#       Unnamed: 0 show_id   type  \
# 2065        2065   s2066  Movie
# 2594        2594   s2595  Movie
# 4442        4442   s4443  Movie
# 8323        8323   s8324  Movie
# 4493        4493   s4494  Movie
#
#                                                   title        director  \
# 2065                                Children of the Sea  Ayumu Watanabe
# 2594  Thomas & Friends: Marvelous Machinery: World o...         Joey So
# 4442                                         Himmatwala      Sajid Khan
# 8323                                  The Good Catholic  Paul Shoulberg
# 4493                           Illang: The Wolf Brigade    Kim Jee-woon
#
#                                                    cast               country  \
# 2065  Mana Ashida, Hiiro Ishibashi, Seishu Uragami, ...  Japan, United States
# 2594  Joseph May, Keith Wickham, Yvonne Grundy, Matt...
# 4442  Ajay Devgn, Tamannaah Bhatia, Paresh Rawal, Za...                 India
# ...

# %%
df[['show_id','type','duration','duration_num','duration_unit']].sample(100)
# Out:
#      show_id     type   duration duration_num duration_unit
# 8335   s8336    Movie    119 min         119            min
# 4853   s4854  TV Show   1 Season           1         season
# 2125   s2126  TV Show  2 Seasons           2         season
# 5957   s5958    Movie     81 min          81            min
# 422     s423    Movie     68 min          68            min
# ...      ...      ...        ...          ...           ...
# 3539   s3540  TV Show   1 Season           1         season
# 2616   s2617    Movie    104 min         104            min
# 4457   s4458    Movie    146 min         146            min
# 1442   s1443  TV Show   1 Season           1         season
# 2969   s2970    Movie    176 min         176            min
#
# [100 rows x 5 columns]

# %%
df['duration_num'] = pd.to_numeric(df['duration_num'])

# %%
df.describe()
# Out:
#         Unnamed: 0  release_year  duration_num
# count  8807.000000   8807.000000        8807.0
# mean   4403.000000   2014.180198      69.84853
# std    2542.506244      8.819312     50.806431
# min       0.000000   1925.000000           1.0
# 25%    2201.500000   2013.000000           2.0
# 50%    4403.000000   2017.000000          88.0
# 75%    6604.500000   2019.000000         106.0
# max    8806.000000   2021.000000         312.0

# %%
df.loc[df['duration_num'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, duration_num, duration_unit]
# Index: []

# %%
df.at[5541,'duration_unit'] = 'min'

# %%
df.describe()
# Out:
#         Unnamed: 0  release_year  duration_num
# count  8807.000000   8807.000000        8807.0
# mean   4403.000000   2014.180198      69.84853
# std    2542.506244      8.819312     50.806431
# min       0.000000   1925.000000           1.0
# 25%    2201.500000   2013.000000           2.0
# 50%    4403.000000   2017.000000          88.0
# 75%    6604.500000   2019.000000         106.0
# max    8806.000000   2021.000000         312.0

# %%
df.duration_num.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.shape[0]
# Out:
# 8807

# %%
df.shape[0]
# Out:
# 8807

# %%
df[['title','country','release_year','duration']].loc[df['duration_num']>120]
# Out:
#                       title  \
# 7                   Sankofa
# 12             Je Suis Karl
# 22          Avvai Shanmughi
# 24                    Jeans
# 26           Minsara Kanavu
# ...                     ...
# 8772  Yamla Pagla Deewana 2
# 8773    Yanda Kartavya Aahe
# 8788           You Carry Me
# 8798               Zed Plus
# 8802                 Zodiac
#
#                                                 country  release_year duration
# 7     United States, Ghana, Burkina Faso, United Kin...          1993  125 min
# 12                              Germany, Czech Republic          2021  127 min
# 22                                                               1996  161 min
# 24                                                India          1998  166 min
# 26                                                               1997  147 min
# ...                                                 ...           ...      ...
# ...

# %%
df[['title','country','release_year','duration']].loc[df['release_year']==1989]
# Out:
#                                                   title  \
# 139                                  Do the Right Thing
# 603                             The Karate Kid Part III
# 928                                    Best of the Best
# 1761                                    Little Monsters
# 2366                      Alexandria: Again and Forever
# 4233                               Bill Hicks: Sane Man
# 4554  Parrot Sketch Not Included: Twenty Years of Mo...
# 5304                                             Mujrim
# 5948                               The Ryan White Story
# 6013                                300 Miles to Heaven
# 6116                              All Dogs Go to Heaven
# 6548                                                Dad
# 6636                             Doubles Cause Troubles
# 7071                 Indiana Jones and the Last Crusade
# 7387                                    Maine Pyar Kiya
# 8523                  The Super Mario Bros. Super Show!
#
# ...

# %%
df[['title','country','release_year','duration']].loc[(df['release_year']==1989) & (df['country'] == 'India') ]
# Out:
#                 title country  release_year duration
# 5304           Mujrim   India          1989  163 min
# 7387  Maine Pyar Kiya   India          1989  192 min

# %%
df[['title','country','release_year','duration']].loc[df['country'] == 'Argentina' ]
# Out:
#                                               title    country  release_year  \
# 275                                     The Kingdom  Argentina          2021
# 303                            Esperando la carroza  Argentina          1985
# 434                                          Okupas  Argentina          2020
# 673                               No Time for Shame  Argentina          2019
# 709                                     Millennials  Argentina          2020
# 769                        From Stress to Happiness  Argentina          2020
# 838                           Soy Rada: Serendipity  Argentina          2021
# 1417                                      Al acecho  Argentina          2019
# 1657                               Notes for My Son  Argentina          2020
# 1713                         Memories of a Teenager  Argentina          2019
# 1733                Carmel: Who Killed Maria Marta?  Argentina          2020
# ...

# %%
df[['title','country','release_year','duration']].loc[(df['release_year']==1989)]
# Out:
#                                                   title  \
# 139                                  Do the Right Thing
# 603                             The Karate Kid Part III
# 928                                    Best of the Best
# 1761                                    Little Monsters
# 2366                      Alexandria: Again and Forever
# 4233                               Bill Hicks: Sane Man
# 4554  Parrot Sketch Not Included: Twenty Years of Mo...
# 5304                                             Mujrim
# 5948                               The Ryan White Story
# 6013                                300 Miles to Heaven
# 6116                              All Dogs Go to Heaven
# 6548                                                Dad
# 6636                             Doubles Cause Troubles
# 7071                 Indiana Jones and the Last Crusade
# 7387                                    Maine Pyar Kiya
# 8523                  The Super Mario Bros. Super Show!
#
# ...

# %%
df[['title','country','release_year','duration']].loc[df['country'] == 'Argentina' ].count()
# Out:
# title           56
# country         56
# release_year    56
# duration        56
# dtype: int64

# %%
df[['title','country','release_year','duration']].loc[df['country'] == 'Argentina' ].count()['title']
# Out:
# np.int64(56)

# %%
df[['title','country','release_year','duration']].loc[df['country'] == 'Argentina' ].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.release_year.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['duration_num'] = pd.to_numeric(df['duration_num'], errors='coerce')

# %%
# df[['title','country','duration_num']].loc[(df['country'] == 'Argentina') & (df['type']=='Movie')].plot.hist(by='duration_num',bins=30)
df[['title','country','duration_num']].loc[(df['country'] == 'Argentina') & (df['type']=='Movie')].plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.head()
# Out:
#    Unnamed: 0 show_id     type                  title         director  \
# 0           0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2  TV Show          Blood & Water
# 2           2      s3  TV Show              Ganglands  Julien Leclercq
# 3           3      s4  TV Show  Jailbirds New Orleans
# 4           4      s5  TV Show           Kota Factory
#
#                                                 cast        country  \
# 0                                                     United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
df.count()
# Out:
# Unnamed: 0       8807
# show_id          8807
# type             8807
# title            8807
# director         8807
# cast             8807
# country          8807
# date_added       8807
# release_year     8807
# rating           8807
# duration         8807
# listed_in        8807
# description      8807
# duration_num     8807
# duration_unit    8807
# dtype: int64

# %%
df.duration_num.loc[df['duration_num']>120].count()
# Out:
# np.int64(1142)

# %%
df[['show_id','type','title','country','release_year','duration']].sort_values(by='release_year', ascending=False)
# Out:
#      show_id     type                                          title  \
# 693     s694    Movie                         Ali & Ratu Ratu Queens
# 781     s782    Movie          Black Holes | The Edge of All We Know
# 762     s763    Movie                                   Sweet & Sour
# 763     s764  TV Show                                    Sweet Tooth
# 764     s765    Movie                   Trippin' with the Kandasamys
# ...      ...      ...                                            ...
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8763   s8764    Movie                WWII: Report from the Aleutians
# 8205   s8206    Movie                           The Battle of Midway
# 7790   s7791    Movie                                 Prelude to War
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#             country  release_year  duration
# 693                          2021   101 min
# 781                          2021    99 min
# ...

# %%
df_temp = df.groupby('release_year').size().rename('movies').reset_index().sort_values(by='release_year',ascending=False)[:20]

# %%
df_temp
# Out:
#     release_year  movies
# 73          2021     592
# 72          2020     953
# 71          2019    1030
# 70          2018    1147
# 69          2017    1032
# 68          2016     902
# 67          2015     560
# 66          2014     352
# 65          2013     288
# 64          2012     237
# 63          2011     185
# 62          2010     194
# 61          2009     152
# 60          2008     136
# 59          2007      88
# 58          2006      96
# 57          2005      80
# 56          2004      64
# 55          2003      61
# 54          2002      51

# %%
df_temp.max()['movies']
# Out:
# np.int64(1147)

# %%
import matplotlib.pyplot as plt
ax = df_temp.plot.bar(x='release_year',y='movies',rot=0)
plt.show()

# %%
df.to_csv('mynetflix.csv')

# %%
clase = [('a',12,'MX'),('b',13,'BR'),('c',14,'USA'),('d',15,'CA')]

# %%
df_clase = pd.DataFrame(clase,columns=['Nombre','Edad','País'])

# %%
df_clase
# Out:
#   Nombre  Edad País
# 0      a    12   MX
# 1      b    13   BR
# 2      c    14  USA
# 3      d    15   CA

# %%
df_clase.sort_values(by='Edad')
# Out:
#   Nombre  Edad País
# 0      a    12   MX
# 1      b    13   BR
# 2      c    14  USA
# 3      d    15   CA

# %%
#df_clase = df_clase.append({'Nombre':'e','Edad':16,'País':'ARG'},ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/gb/nv8xcn1n2fj8nvh2rrjytk0r0000gn/T/ipykernel_2361/4198928486.py in ?()
# ----> 1 df_clase = df_clase.append({'Nombre':'e','Edad':16,'País':'ARG'},ignore_index = True)
#
# /opt/anaconda3/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
nuevo = pd.DataFrame([{
    'Nombre': 'e',
    'Edad': 16,
    'País': 'ARG'
}])

df_clase = pd.concat([df_clase, nuevo], ignore_index=True)

# %%
df_clase
# Out:
#   Nombre  Edad País
# 0      a    12   MX
# 1      b    13   BR
# 2      c    14  USA
# 3      d    15   CA
# 4      e    16  ARG

# %%
df_clase.sort_values(by='Edad', ascending=False)
# Out:
#   Nombre  Edad País
# 4      e    16  ARG
# 3      d    15   CA
# 2      c    14  USA
# 1      b    13   BR
# 0      a    12   MX

# %%
df_clase.drop(df_clase.index[1])
# Out:
#   Nombre  Edad País
# 0      a    12   MX
# 2      c    14  USA
# 3      d    15   CA
# 4      e    16  ARG

# %%
df_clase.drop(df_clase.index[[2,3]])
# Out:
#   Nombre  Edad País
# 0      a    12   MX
# 1      b    13   BR
# 4      e    16  ARG

# %%
df_clase.at[3,'Nombre'] = 'José'

# %%
df_clase
# Out:
#   Nombre  Edad País
# 0      a    12   MX
# 1      b    13   BR
# 2      c    14  USA
# 3   José    15   CA
# 4      e    16  ARG

# %%
df_clase.loc[1:2,['Edad','País']]=[32,'ARG']

# %%
df_clase
# Out:
#   Nombre  Edad País
# 0      a    12   MX
# 1      b    32  ARG
# 2      c    32  ARG
# 3   José    15   CA
# 4      e    16  ARG

# %%
df_clase
# Out:
#   Nombre  Edad País
# 0      a    12   MX
# 1      b    32  ARG
# 2      c    32  ARG
# 3   José    15   CA
# 4      e    16  ARG

# %%
df_clase.replace('MX','mx',inplace=True)

# %%
df_clase
# Out:
#   Nombre  Edad País
# 0      a    12   mx
# 1      b    32  ARG
# 2      c    32  ARG
# 3   José    15   CA
# 4      e    16  ARG

# %%
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
sns.pairplot(df,hue='rating')
plt.show()

# %%
sns.pairplot(df,hue='type')
plt.show()
