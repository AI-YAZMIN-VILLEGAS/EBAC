# %% [markdown]
# # Base de datos no relacionales

# %%
pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 985.9/985.9 kB 19.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pymongo]m1/2 [pymongo]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymongo import MongoClient

client = MongoClient('mongodb+srv://user:merci128@cluster0.f3rbisa.mongodb.net/')

# %%
filter={'username':'user'}
result = client['new_db']['db'].find(filter=filter)

# %%
from pymongo import MongoClient

uri = "mongodb+srv://user:merci128@cluster0.f3rbisa.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

client = MongoClient(uri)

# %%
filter = {'title': 'The Matrix'}
result = client['sample_mflix']['movies'].find(filter=filter)

# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)

for doc in result:
    pp.pprint(doc)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[19], line 4
#       1 import pprint
#       2 pp = pprint.PrettyPrinter(indent=4)
# ----> 4 for doc in result:
#       5     pp.pprint(doc)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pymongo/synchronous/cursor.py:1166, in Cursor.__next__(self)
#    1165 def __next__(self) -> _DocumentType:
# -> 1166     return self.next()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pymongo/synchronous/cursor.py:1142, in Cursor.next(self)
#    1140 if self._empty:
#    1141     raise StopIteration
# -> 1142 if len(self._data) or self._refresh():
#    1143     return self._data.popleft()
#    1144 else:
#
# File /opt/anaconda3/lib/python3.13/site-packages/pymongo/synchronous/cursor.py:1090, in Cursor._refresh(self)
#    1068         raise InvalidOperation(
# ...
