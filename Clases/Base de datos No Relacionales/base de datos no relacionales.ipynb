# %% [markdown]
# # Base de datos no relacionales

# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymongo import MongoClient

client = MongoClient('mongodb+srv://user:merci128@cluster0.f3rbisa.mongodb.net/')

# %%
#filter={'username':'user'}
#result = client['new_db']['db'].find(filter=filter)

# %%
#filter = {'title': 'The Matrix'}
#result = client['sample_mflix']['movies'].find(filter=filter)

# %%
filter = {'airline': 'Virgin America'}
result = client['new_db']['db'].find(filter=filter)

# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)

for doc in result:
    pp.pprint(doc)
# Out:
# {   '_id': ObjectId('6a5858f083644592e2433c86'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'neutral',
#     'airline_sentiment_confidence': 1.0,
#     'name': 'cairdin',
#     'retweet_count': 0,
#     'text': '@VirginAmerica What @dhepburn said.',
#     'tweet_created': '2015-02-24 11:35:52 -0800',
#     'tweet_id': 570306133677760513,
#     'user_timezone': 'Eastern Time (US & Canada)'}
# {   '_id': ObjectId('6a5858f083644592e2433ca2'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'negative',
#     'airline_sentiment_confidence': 1.0,
#     'name': 'blackjackpro911',
#     'negativereason': 'Bad Flight',
#     'negativereason_confidence': 1.0,
#     'retweet_count': 0,
#     'text': "@VirginAmerica amazing to me that we can't get any cold air from "
#             'the vents. #VX358 #noair #worstflightever #roasted #SFOtoBOS',
#     'tweet_coord': [42.361016, -71.02000488],
#     'tweet_created': '2015-02-24 05:05:28 -0800',
# ...

# %%
filter = {"$and":[{'airline': 'Virgin America'},{'airline_sentiment':'neutral'}]}
result = client['new_db']['db'].find(filter=filter)

# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)

for doc in result:
    pp.pprint(doc)
# Out:
# {   '_id': ObjectId('6a5858f083644592e2433c86'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'neutral',
#     'airline_sentiment_confidence': 1.0,
#     'name': 'cairdin',
#     'retweet_count': 0,
#     'text': '@VirginAmerica What @dhepburn said.',
#     'tweet_created': '2015-02-24 11:35:52 -0800',
#     'tweet_id': 570306133677760513,
#     'user_timezone': 'Eastern Time (US & Canada)'}
# {   '_id': ObjectId('6a5858f083644592e2433d22'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'neutral',
#     'airline_sentiment_confidence': 1.0,
#     'name': 'HeatherWhoo',
#     'retweet_count': 0,
#     'text': '@VirginAmerica my drivers license is expired by a little over a '
#             'month. Can I fly Friday morning using my expired license?',
#     'tweet_created': '2015-02-22 11:10:27 -0800',
#     'tweet_id': 569574961158815745}
# {   '_id': ObjectId('6a5858f083644592e2433d3f'),
#     'airline': 'Virgin America',
# ...

# %%
db = client['new_db']
mycollection = db['db']

result = mycollection.insert_one(
    {
        'tweet_id':'0'
    }
)

# %%
db = client['new_db']
mycollection = db['db']

result = mycollection.insert_one(
    {
        'tweet_id':'1',
        'airline':'fake airline'
    }
)

# %%
db = client['new_db']
mycollection = db['db']

mycollection.update_one(
    {
        'tweet_id':'1'
    },
    {
        '$set':{'airline':'so fake airline'}
    }
)
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff00000000000001c6'), 'opTime': {'ts': Timestamp(1784843639, 2), 't': 454}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1784843639, 2), 'signature': {'hash': b'\xde p\xfa2\xbd\x98\x0b\x89\x9f\xf2\xe7\xd5LfW\x86\xfc9=', 'keyId': 7606747725324877826}}, 'operationTime': Timestamp(1784843639, 2), 'updatedExisting': True}, acknowledged=True)
