# %%
#PAQUETE NUMPY Y PROBLEMAS ESTADISTICOS
import pandas as pd
import numpy as np
import os

df = pd.read_csv('fifa_eda.csv')

# %%
df.sample(5)
# Out:
#           ID          Name  Age  Nationality  Overall  Potential  \
# 7158  210566  L. Chiaretti   30       Brazil       68         68
# 8257  221323    J. Onguéné   20     Cameroon       67         81
# 3249  197900     P. Kasami   26  Switzerland       72         73
# 5732  211736   R. Leipertz   25      Germany       69         72
# 3267  215056  C. Carbonero   27     Colombia       72         72
#
#                       Club   Value  Wage Preferred Foot  \
# 7158                Foggia   850.0   2.0           Left
# 8257  FC Red Bull Salzburg  1500.0   8.0          Right
# 3249               FC Sion  3700.0  22.0           Left
# 5732      FC Ingolstadt 04  1300.0  12.0           Left
# 3267        Deportivo Cali  3200.0   3.0          Right
#
#       International Reputation  Skill Moves Position  Joined  \
# 7158                       1.0          3.0      CAM    2018
# 8257                       1.0          2.0      LCB    2018
# ...

# %%
age_np = df['Age'].to_numpy()
height_np = df['Height'].to_numpy()
weight_np = df['Weight'].to_numpy()
overall_np = df['Overall'].to_numpy()
potential_np = df['Potential'].to_numpy()
print(age_np)
print(height_np)
print(weight_np)
print(overall_np)
print(potential_np)
# Out:
# [31 33 26 ... 16 17 16]
# [5.58333333 6.16666667 5.75       ... 5.66666667 5.83333333 5.83333333]
# [159. 183. 150. ... 148. 154. 176.]
# [94 94 92 ... 47 47 46]
# [94 94 93 ... 67 66 66]

# %%
type(age_np)
# Out:
# numpy.ndarray

# %%
age_np[0:10]
# Out:
# array([31, 33, 26, 27, 27, 27, 32, 31, 32, 25])

# %%
np.count_nonzero(age_np)
# Out:
# 18207

# %%
np.shape(age_np)
# Out:
# (18207,)

# %%
df['Age'][0:10]
# Out:
# 0    31
# 1    33
# 2    26
# 3    27
# 4    27
# 5    27
# 6    32
# 7    31
# 8    32
# 9    25
# Name: Age, dtype: int64

# %%
np.where(age_np > 30, age_np, 0)
# Out:
# array([31, 33,  0, ...,  0,  0,  0])

# %%
ixoldest = np.argmax(age_np)
age_np[ixoldest]
# Out:
# np.int64(45)

# %%
media = age_np.mean()
format_medida = '{:.2f}'.format(media)
print('La media de las edades es: ',format_medida,' años')
# Out:
# La media de las edades es:  25.12  años

# %%
for i in range(0,100,5):
    print(i,"%: ",np.percentile(age_np, i))
# Out:
# 0 %:  16.0
# 5 %:  18.0
# 10 %:  19.0
# 15 %:  20.0
# 20 %:  21.0
# 25 %:  21.0
# 30 %:  22.0
# 35 %:  23.0
# 40 %:  23.0
# 45 %:  24.0
# 50 %:  25.0
# 55 %:  25.0
# 60 %:  26.0
# 65 %:  27.0
# 70 %:  28.0
# 75 %:  28.0
# 80 %:  29.0
# 85 %:  30.0
# 90 %:  32.0
# 95 %:  33.0

# %%
vals, counts = np.unique(age_np,return_counts=True)
index = np.argmax(counts)
moda = vals[index]
print(f'La moda de la edad de los jugadores es: = {moda:.2f} años')
# Out:
# La moda de la edad de los jugadores es: = 21.00 años

# %%
counts
# Out:
# array([  42,  289,  732, 1024, 1240, 1423, 1340, 1332, 1358, 1319, 1387,
#        1162, 1101,  959,  917,  707,  574,  408,  404,  196,  127,   82,
#          37,   25,   13,    5,    1,    2,    1])

# %%
mediana = np.median(age_np)
print(f'La mediana de la edad de los jugadores es: = {mediana:.2f} años')
# Out:
# La mediana de la edad de los jugadores es: = 25.00 años

# %%
desvstd = age_np.std()
print(f'La desviación estándar de la edad de los jugadores es: = {desvstd:.2f} años')
# Out:
# La desviación estándar de la edad de los jugadores es: = 4.67 años

# %%
import matplotlib.pyplot as plt
plt.hist(age_np)
plt.title('Histograma de edades')
plt.show()

# %%
import seaborn as sns

sns.set_style('darkgrid')
sns.displot(age_np)

# %%
age_np
# Out:
# array([31, 33, 26, ..., 16, 17, 16])

# %%
sns.set_style('darkgrid')
sns.displot(age_np)
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.title('Distribución de edades de los jugadores')
plt.axvline(age_np.mean(), color='red', ls='--')
plt.axvline(mediana, color='blue', ls='-')
plt.axvline(moda, color='green', ls='-')

# %%
sns.set_style('darkgrid')
sns.displot(age_np)
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.title('Distribución de edades de los jugadores')
# Out:
# Text(0.5, 1.0, 'Distribución de edades de los jugadores')

# %%
print('Numero total de jugadores: ', len(age_np))
# Out:
# Numero total de jugadores:  18207

# %%
age_np[18206]
# Out:
# np.int64(16)

# %%
print('La maxima edad de los jugadores es: ', np.amax(age_np))
print('La maxima edad de los jugadores es: ', np.amin(age_np))
# Out:
# La maxima edad de los jugadores es:  45
# La maxima edad de los jugadores es:  16

# %%
#age_top = np.concatenate(age_np)
age_top = np.array(age_np)
print(age_np[0:10])
print(age_top[0:10])
# Out:
# [31 33 26 27 27 27 32 31 32 25]
# [31 33 26 27 27 27 32 31 32 25]

# %%
age_top_num = np.sort(age_top)
print(age_top_num)
# Out:
# [16 16 16 ... 44 44 45]

# %%
age_top_num_rev = age_top_num[::-1]
print(age_top_num_rev)
# Out:
# [45 44 44 ... 16 16 16]

# %%
df.sort_values(by='Age',ascending=False).head(20)
# Out:
#            ID             Name  Age        Nationality  Overall  Potential  \
# 4741   140029         O. Pérez   45             Mexico       71         71
# 18183   53748    K. Pilkington   44            England       48         48
# 17726   51963        T. Warner   44  Trinidad & Tobago       53         53
# 10545  140183      S. Narazaki   42              Japan       65         65
# 7225   142998         C. Muñoz   41          Argentina       68         68
# 1120   156092        J. Villar   41           Paraguay       77         77
# 12192  208927     H. Sulaimani   41       Saudi Arabia       63         63
# 15426   18745         M. Tyler   41            England       59         59
# 4228     3665         B. Nivet   41             France       71         71
# 10356   49511         F. Kippe   40             Norway       65         65
# 16264   28157  P. van der Vlag   40        Netherlands       58         58
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

x = df.sort_values(by='Age',ascending=False).head(20)[['Name', 'Age']]
# Out:
#                   Name  Age
# 4741          O. Pérez   45
# 18183    K. Pilkington   44
# 17726        T. Warner   44
# 10545      S. Narazaki   42
# 7225          C. Muñoz   41
# 1120         J. Villar   41
# 12192     H. Sulaimani   41
# 15426         M. Tyler   41
# 4228          B. Nivet   41
# 10356         F. Kippe   40
# 16264  P. van der Vlag   40
# 9484       B. Castillo   40
# 4187      C. Lucchetti   40
# 2821        S. Bertoli   40
# 3550       S. Nakamura   40
# 1294       A. Bizzarri   40
# 14129      Y. Nakazawa   40
# 41           G. Buffon   40
# 864             Hilton   40
# 12453          W. Díaz   40

# %%
x
# Out:
#                   Name  Age
# 4741          O. Pérez   45
# 18183    K. Pilkington   44
# 17726        T. Warner   44
# 10545      S. Narazaki   42
# 7225          C. Muñoz   41
# 1120         J. Villar   41
# 12192     H. Sulaimani   41
# 15426         M. Tyler   41
# 4228          B. Nivet   41
# 10356         F. Kippe   40
# 16264  P. van der Vlag   40
# 9484       B. Castillo   40
# 4187      C. Lucchetti   40
# 2821        S. Bertoli   40
# 3550       S. Nakamura   40
# 1294       A. Bizzarri   40
# 14129      Y. Nakazawa   40
# 41           G. Buffon   40
# 864             Hilton   40
# 12453          W. Díaz   40

# %%
ax = x.plot.barh(y='Age',x='Name',color='b',title='Top 10 Edades')

# %%
ax = x[::-1].plot.barh(y='Age',x='Name',color='b',title='Top 10 Edades')
